# %% [markdown]
# <a href="https://colab.research.google.com/github/rajagopalmotivate/WiproMultiModalClassifierOffensive/blob/main/Copy_of_Enduser_Declares_Active_Features_to_improve_X_Multimodal_classifer_ver_8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ***Wipro's Intelligent Multimodal platform ***
# ## ***A innovative path to partnering for revenue growth ***

# %% [markdown]
# # Step Pre 0: Install stuff that require restart of runtime

# %%
# !pip install pytesseract
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pytesseract
#   Downloading pytesseract-0.3.10-py3-none-any.whl (14 kB)
# Collecting Pillow>=8.0.0
#   Downloading Pillow-9.3.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.2 MB)
#      |████████████████████████████████| 3.2 MB 19.0 MB/s
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.8/dist-packages (from pytesseract) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging>=21.3->pytesseract) (3.0.9)
# Installing collected packages: Pillow, pytesseract
#   Attempting uninstall: Pillow
#     Found existing installation: Pillow 7.1.2
#     Uninstalling Pillow-7.1.2:
#       Successfully uninstalled Pillow-7.1.2
# Successfully installed Pillow-9.3.0 pytesseract-0.3.10

# %%
 

# !sudo apt install tesseract-ocr
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'sudo apt autoremove' to remove it.
# The following additional packages will be installed:
#   tesseract-ocr-eng tesseract-ocr-osd
# The following NEW packages will be installed:
#   tesseract-ocr tesseract-ocr-eng tesseract-ocr-osd
# 0 upgraded, 3 newly installed, 0 to remove and 20 not upgraded.
# Need to get 4,795 kB of archives.
# After this operation, 15.8 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 tesseract-ocr-eng all 4.00~git24-0e00fe6-1.2 [1,588 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic/universe amd64 tesseract-ocr-osd all 4.00~git24-0e00fe6-1.2 [2,989 kB]
# Get:3 http://archive.ubuntu.com/ubuntu bionic/universe amd64 tesseract-ocr amd64 4.00~git2288-10f4998a-2 [218 kB]
# Fetched 4,795 kB in 3s (1,379 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 3.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package tesseract-ocr-eng.
# (Reading database ... 124013 files and directories currently installed.)
# Preparing to unpack .../tesseract-ocr-eng_4.00~git24-0e00fe6-1.2_all.deb ...
# Unpacking tesseract-ocr-eng (4.00~git24-0e00fe6-1.2) ...
# Selecting previously unselected package tesseract-ocr-osd.
# Preparing to unpack .../tesseract-ocr-osd_4.00~git24-0e00fe6-1.2_all.deb ...
# Unpacking tesseract-ocr-osd (4.00~git24-0e00fe6-1.2) ...
# Selecting previously unselected package tesseract-ocr.
# Preparing to unpack .../tesseract-ocr_4.00~git2288-10f4998a-2_amd64.deb ...
# Unpacking tesseract-ocr (4.00~git2288-10f4998a-2) ...
# Setting up tesseract-ocr-osd (4.00~git24-0e00fe6-1.2) ...
# Setting up tesseract-ocr-eng (4.00~git24-0e00fe6-1.2) ...
# Setting up tesseract-ocr (4.00~git2288-10f4998a-2) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...

# %%
# !sudo apt install libtesseract-dev
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'sudo apt autoremove' to remove it.
# The following additional packages will be installed:
#   libleptonica-dev
# The following NEW packages will be installed:
#   libleptonica-dev libtesseract-dev
# 0 upgraded, 2 newly installed, 0 to remove and 20 not upgraded.
# Need to get 2,755 kB of archives.
# After this operation, 13.8 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libleptonica-dev amd64 1.75.3-3 [1,308 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libtesseract-dev amd64 4.00~git2288-10f4998a-2 [1,447 kB]
# Fetched 2,755 kB in 3s (944 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 2.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package libleptonica-dev.
# (Reading database ... 124060 files and directories currently installed.)
# Preparing to unpack .../libleptonica-dev_1.75.3-3_amd64.deb ...
# Unpacking libleptonica-dev (1.75.3-3) ...
# Selecting previously unselected package libtesseract-dev.
# Preparing to unpack .../libtesseract-dev_4.00~git2288-10f4998a-2_amd64.deb ...
# Unpacking libtesseract-dev (4.00~git2288-10f4998a-2) ...
# Setting up libleptonica-dev (1.75.3-3) ...
# Setting up libtesseract-dev (4.00~git2288-10f4998a-2) ...

# %%
# !pip install Pillow==9.0.0
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting Pillow==9.0.0
#   Downloading Pillow-9.0.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.3 MB)
#      |████████████████████████████████| 4.3 MB 7.0 MB/s
# Installing collected packages: Pillow
#   Attempting uninstall: Pillow
#     Found existing installation: Pillow 7.1.2
#     Uninstalling Pillow-7.1.2:
#       Successfully uninstalled Pillow-7.1.2
# Successfully installed Pillow-9.0.0

# %%
import os
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

# 1. Authenticate and create the PyDrive client.
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# %% [markdown]
# ## Step 0: Fetch the dataset
# download the images and 3 CSV file

# %%
#images
#https://drive.google.com/drive/folders/1GGy63-KlrSLjhpbTNGV-ObS_M4JMxeLr?usp=share_link
#https://drive.google.com/drive/folders/1hKLOtpVmF45IoBmJPwojgq6XraLtHmV6

# %%
#CSV 
#https://drive.google.com/drive/folders/1ckOGoRmMwCEFo-k3UX7J2lnzg495WIS5?usp=share_link

# %%
# !pip install -U -q PyDrive
import os
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

# 1. Authenticate and create the PyDrive client.
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# choose a local (colab) directory to store the data.
local_download_path = 'nandriImages/'
try:
    os.makedirs(local_download_path)
except: pass

local_download_path = 'nandriCSV/'
try:
    os.makedirs(local_download_path)
except: pass

# %%
# !pwd
# Out:
# /content

# %%
# 2. Auto-iterate using the query syntax
#    https://developers.google.com/drive/v2/web/search-parameters

 
file_list = drive.ListFile(
    {'q': "'1ckOGoRmMwCEFo-k3UX7J2lnzg495WIS5' in parents"}).GetList()  #use your own folder ID here

for f in file_list:
    # 3. Create & download by id.
    print('title: %s, id: %s' % (f['title'], f['id']))
    fname = f['title']
    print('downloading to {}'.format(fname))
    f_ = drive.CreateFile({'id': f['id']})
    f_.GetContentFile(fname)
# Out:
# title: Training_meme_dataset.csv, id: 1BnQ7aH7eSnGJyJzYBYEUEvCxmmguW2VX
# downloading to Training_meme_dataset.csv
# title: Testing_meme_dataset.csv, id: 1e954gyIL3NWHRjz6V4ayJrx3Mvvxpstc
# downloading to Testing_meme_dataset.csv
# title: Validation_meme_dataset.csv, id: 1MI0AskX4eIr-CstwlZYm0PBH0tU_c8RN
# downloading to Validation_meme_dataset.csv

# %%
# 2. Auto-iterate using the query syntax
#    https://developers.google.com/drive/v2/web/search-parameters

 
file_list = drive.ListFile(
    {'q': "'1GGy63-KlrSLjhpbTNGV-ObS_M4JMxeLr' in parents"}).GetList()  #use your own folder ID here

if False:
  for f in file_list:
    # 3. Create & download by id.
    print('title: %s, id: %s' % (f['title'], f['id']))
    fname = f['title']
    print('downloading to {}'.format(fname))
    f_ = drive.CreateFile({'id': f['id']})
    f_.GetContentFile(fname)

# %%
#https://drive.google.com/drive/folders/1qvWrxquhgW55O17sPfXGQ8Er4LB0oqxp?usp=share_link

file_list = drive.ListFile(
    {'q': "'1qvWrxquhgW55O17sPfXGQ8Er4LB0oqxp' in parents"}).GetList()  #use your own folder ID here

for f in file_list:
    # 3. Create & download by id.
    print('title: %s, id: %s' % (f['title'], f['id']))
    fname = f['title']
    print('downloading to {}'.format(fname))
    f_ = drive.CreateFile({'id': f['id']})
    f_.GetContentFile(fname)
# Out:
# title: Labelled Images-20221211T030207Z-001.zip, id: 1OkHGRko1LUNN6eKz6uUk38q_cYtL7udy
# downloading to Labelled Images-20221211T030207Z-001.zip

# %%
# !ls "Labelled Images-20221211T030207Z-001.zip"
# Out:
# 'Labelled Images-20221211T030207Z-001.zip'

# %%
import zipfile


zip_ref = zipfile.ZipFile("Labelled Images-20221211T030207Z-001.zip", 'r')
zip_ref.extractall("nandri/")
zip_ref.close()

# %% [markdown]
# # Step 1: Understand the problem statement /  Explore dataset

# %%
# %cd /content/nandri/Labelled Images
# Out:
# /content/nandri/Labelled Images

# %%
# !pwd
# Out:
# /content/nandri/Labelled Images

# %% [markdown]
# ## Step 1a: Understand the problem statment

# %%
import pandas as pd

# %% [markdown]
# # Step 2: Domain expert declares the features to be explored

# %% [markdown]
# ## Step 2.A: What could be the features to look for ? Just jot it down. And the AI will auto consider those as part of ZERO SHOT CLASSIFER to teach the AI about features!
#
# This is UI for Wipro Domain Experts. Just type here!
#
# E.g. (HLS domain consultants - can suggest features to look out for such as 'hairline fracture', 'nuemonia' .  )

# %%
What_could_be_classes_ZEROSHOT = "offensive, non offensive, racist, non-racist, toxic, severe toxic, pleasant in meaning, obsence, inflammatory, insult, profanity, slavery " #@param {type:"string"}

# %%
ZEROSHOTcandidate_labels = What_could_be_classes_ZEROSHOT.split(",")
for i in range(len(ZEROSHOTcandidate_labels)):
  ZEROSHOTcandidate_labels[i] = ZEROSHOTcandidate_labels[i].strip()


ZEROSHOTcandidate_labels
# Out:
# ['offensive',
#  'non offensive',
#  'racist',
#  'non-racist',
#  'toxic',
#  'severe toxic',
#  'pleasant in meaning',
#  'obsence',
#  'inflammatory',
#  'insult',
#  'profanity',
#  'slavery']

# %% [markdown]
# ## Step 2.B: What could be the features to look for in the image ?  And the AI will auto consider those as part of  NATURAL LANGUAGE VISUAL REASONING (NLVR) MULTIMODAL TASK !
# Just jot it down.

# %%
What_could_be_VISUALREASONING_Factors = "offensive, non offensive,  extremely offensive,  nudity or sexual, violence" #@param {type:"string"}
#What_could_be_VISUALREASONING_Factors = "offensive" #@param {type:"string"}

# %%
What_could_be_VISUALREASONING_Factors2 = "abuse of women, black people as slaves, racist behavior" #@param {type:"string"}
#What_could_be_VISUALREASONING_Factors2 = "black people as slaves, violence against women, man attacking women " #@param {type:"string"}

# %%
What_could_be_supplemental_VISUALREASONING_Factors = "is a clipart, is filled with text" #@param {type:"string"}
#What_could_be_supplemental_VISUALREASONING_Factors = "is filled with text, is a clipart " #@param {type:"string"}

# %%
VISUALREASONING_Factors = What_could_be_VISUALREASONING_Factors.split(",")
for i in range(len(VISUALREASONING_Factors)):
  VISUALREASONING_Factors[i] = VISUALREASONING_Factors[i].strip()

# %%
VISUALREASONING_Factors2 = What_could_be_VISUALREASONING_Factors2.split(",")
for i in range(len(VISUALREASONING_Factors2)):
  VISUALREASONING_Factors2[i] = VISUALREASONING_Factors2[i].strip()

# %%
VISUALREASONING_Factors3 = What_could_be_supplemental_VISUALREASONING_Factors.split(",")
for i in range(len(VISUALREASONING_Factors3)):
  VISUALREASONING_Factors3[i] = VISUALREASONING_Factors3[i].strip()

# %%
for i in range(len(VISUALREASONING_Factors)):
  print ( "This image contains " + VISUALREASONING_Factors[i] + " content")
for i in range(len(VISUALREASONING_Factors2)):
  print("This image shows " + VISUALREASONING_Factors2[i])
for i in range(len(VISUALREASONING_Factors3)):
  print("This image " + VISUALREASONING_Factors3[i])
# Out:
# This image contains offensive content
# This image contains non offensive content
# This image contains extremely offensive content
# This image contains nudity or sexual content
# This image contains violence content
# This image shows abuse of women
# This image shows black people as slaves
# This image shows racist behavior
# This image is a clipart
# This image is filled with text

# %%
VISUALREASONING_FactorsALL_ColomnName = []
VISUALREASONING_FactorsALL_Reasoning = []

for i in range(len(VISUALREASONING_Factors)):
  VISUALREASONING_FactorsALL_ColomnName.append( "NLVR."+VISUALREASONING_Factors[i])
  VISUALREASONING_FactorsALL_Reasoning.append("This image contains " + VISUALREASONING_Factors[i] + " content")
for i in range(len(VISUALREASONING_Factors2)):
  VISUALREASONING_FactorsALL_ColomnName.append("NLVR."+VISUALREASONING_Factors2[i])
  VISUALREASONING_FactorsALL_Reasoning.append("This image shows " + VISUALREASONING_Factors2[i])
for i in range(len(VISUALREASONING_Factors3)):
  VISUALREASONING_FactorsALL_ColomnName.append("NLVR."+VISUALREASONING_Factors3[i])
  VISUALREASONING_FactorsALL_Reasoning.append("This image " + VISUALREASONING_Factors3[i])

# %%
for i in range(len (VISUALREASONING_FactorsALL_ColomnName)):
  print( str(i) + ". " + VISUALREASONING_FactorsALL_ColomnName[i] + "   ---------------------      "   + VISUALREASONING_FactorsALL_Reasoning[i])
# Out:
# 0. NLVR.offensive   ---------------------      This image contains offensive content
# 1. NLVR.non offensive   ---------------------      This image contains non offensive content
# 2. NLVR.extremely offensive   ---------------------      This image contains extremely offensive content
# 3. NLVR.nudity or sexual   ---------------------      This image contains nudity or sexual content
# 4. NLVR.violence   ---------------------      This image contains violence content
# 5. NLVR.abuse of women   ---------------------      This image shows abuse of women
# 6. NLVR.black people as slaves   ---------------------      This image shows black people as slaves
# 7. NLVR.racist behavior   ---------------------      This image shows racist behavior
# 8. NLVR.is a clipart   ---------------------      This image is a clipart
# 9. NLVR.is filled with text   ---------------------      This image is filled with text

# %% [markdown]
# # Step 3: Extract features

# %%
dfraw_Test = pd.read_csv("/content/Testing_meme_dataset.csv")
dfraw_Test["DATASET"] = "TEST"
dfraw_Train = pd.read_csv("/content/Training_meme_dataset.csv")
dfraw_Train["DATASET"] = "TRAIN"
dfraw_Val = pd.read_csv("/content/Validation_meme_dataset.csv")
dfraw_Val["DATASET"] = "VAL"

dfraw = dfraw_Train.append(dfraw_Val, ignore_index=True) 
dfraw = dfraw.append(dfraw_Test, ignore_index=True )

# %%
# !pwd
# Out:
# /content/nandri/Labelled Images

# %%
 
train_file_path = 'processed4temp.csv'

dfraw = pd.read_csv(train_file_path)
 

#dfraw = pd.read_csv( 'processed2Gold.csv')

# %%
del dfraw['Unnamed: 0']

# %%
dfraw.head(2)
# Out:
#         image_name                                           sentence  \
# 0  LJ3r8Gy.jpg.png  OFFICIAL BERNIE SANDERS DRINKING GAME ! Every ...
# 1      qDnIIHA.png  2:28 PM THIS IS A WALL INSIDE A NAZI GAS CHAMB...
#
#           label DATASET  CAT.isOffensiveText1  NUM.isOffensiveText1softm0  \
# 0  Non-offensiv   TRAIN                   1.0                         0.5
# 1     offensive   TRAIN                   1.0                         0.5
#
#    NUM.isOffensiveText1softm1  NUM.offensive  NUM.inflammatory  NUM.profanity  \
# 0                         0.5          0.825             0.814          0.306
# 1                         0.5          0.996             0.991          0.361
#
#    ...  NUM.NLVR.black people as slaves1  CAT.NLVR.racist behavior  \
# 0  ...                             0.001                       0.0
# 1  ...                             0.036                       1.0
#
#    NUM.NLVR.racist behavior0  NUM.NLVR.racist behavior1  \
# 0                      0.909                      0.091
# 1                      0.340                      0.660
#
#    CAT.NLVR.is a clipart  NUM.NLVR.is a clipart0  NUM.NLVR.is a clipart1  \
# 0                    1.0                   0.002                   0.998
# 1                    1.0                   0.001                   0.999
#
#    CAT.NLVR.is filled with text  NUM.NLVR.is filled with text0  \
# 0                           1.0                            0.0
# 1                           1.0                            0.0
#
#    NUM.NLVR.is filled with text1
# 0                            1.0
# 1                            1.0
#
# [2 rows x 49 columns]

# %%
#dfraw = dfraw[0:400]

# %%
from PIL import Image

#image1 = Image.open( dfraw['image_name'][2])
#display(image1)

# %% [markdown]
# ## Step 2a. Extract image features and add to dataset
#  Apply "Declarative Feature extraction" from Visual Language Foundation models such as CLIP, VLIT, etc
#  We can extract features

# %%
import cv2 
import pytesseract

# %%
countofRecordstoProcess  = len(dfraw )

# %%
OCR_tesseract_config = r'--psm 1'

if False:
  for i in range( countofRecordstoProcess ):  
    img = cv2.imread(dfraw['image_name'][i] )
    ocrtext = pytesseract.image_to_string(img, config=OCR_tesseract_config) 
    dfraw.at[i , "OCR" ] =  ocrtext

# %%
# !pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting transformers
#   Downloading transformers-4.25.1-py3-none-any.whl (5.8 MB)
#      |████████████████████████████████| 5.8 MB 6.2 MB/s
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.8/dist-packages (from transformers) (6.0)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Downloading tokenizers-0.13.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.6 MB)
#      |████████████████████████████████| 7.6 MB 67.3 MB/s
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.8/dist-packages (from transformers) (2022.6.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from transformers) (2.23.0)
# Collecting huggingface-hub<1.0,>=0.10.0
#   Downloading huggingface_hub-0.11.1-py3-none-any.whl (182 kB)
#      |████████████████████████████████| 182 kB 73.4 MB/s
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from transformers) (21.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.8/dist-packages (from transformers) (4.64.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.8/dist-packages (from transformers) (1.21.6)
# Requirement already satisfied: filelock in /usr/local/lib/python3.8/dist-packages (from transformers) (3.8.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.8/dist-packages (from huggingface-hub<1.0,>=0.10.0->transformers) (4.4.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging>=20.0->transformers) (3.0.9)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests->transformers) (2022.9.24)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests->transformers) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->transformers) (2.10)
# Installing collected packages: tokenizers, huggingface-hub, transformers
# Successfully installed huggingface-hub-0.11.1 tokenizers-0.13.2 transformers-4.25.1

# %%
def understnadImage(image1 , text):
  encoding = processor([image1, image1], text, return_tensors="pt")
  # forward pass
  outputs = model(input_ids=encoding.input_ids, pixel_values=encoding.pixel_values.unsqueeze(0))
  logits = outputs.logits
  idx = logits.argmax(-1).item()
  #print("Predicted answer:", model.config.id2label[idx]),
  return idx

# %%
from scipy.special import softmax

# %%
#image1 = Image.open( dfraw['image_name'][2]  )
#image1 = image1.convert('RGB')
#display(image1)

#understnadImage1(image1 , "The image contains offensive content.")

# %%
from transformers import AutoTokenizer, AutoModelForSequenceClassification

tokenizerHate = AutoTokenizer.from_pretrained("elozano/tweet_offensive_eval")

classifierHate = AutoModelForSequenceClassification.from_pretrained("elozano/tweet_offensive_eval")
# Out:
# Downloading:   0%|          | 0.00/327 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/798k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/456k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/239 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/867 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/499M [00:00<?, ?B/s]

# %%
import torch

# %%
def isOffensiveText(text1):
  inputs = tokenizerHate(text1, return_tensors="pt")
  with torch.no_grad():
    logits = classifierHate(**inputs).logits
  predicted_class_id = logits.argmax().item()
  #print(model.config.id2label[predicted_class_id])
  return predicted_class_id

# %%
def isOffensiveText1(text1):
  inputs = tokenizerHate(text1, return_tensors="pt")
  with torch.no_grad():
    outputs = classifierHate(**inputs)
    logits = outputs.logits
  predicted_class_id = logits.argmax().item()
  scores = outputs[0][0].detach().numpy()
  scores = softmax(scores)    
  #print(model.config.id2label[predicted_class_id])
  return predicted_class_id, round ( scores[0] , 1)  , round ( scores[1] , 1)

# %%
for i in range( countofRecordstoProcess ):  
  text1 =  dfraw['sentence'][i] 
  text1 = str(text1)
  isOffensiveTextans, isOffensiveTextans0, isOffensiveTextans1 = isOffensiveText1(text1)
  dfraw.at[i , "CAT.isOffensiveText1" ] =   isOffensiveTextans  
  dfraw.at[i , "NUM.isOffensiveText1softm0" ] =   round (isOffensiveTextans0, 3)
  dfraw.at[i , "NUM.isOffensiveText1softm1" ] =   round (isOffensiveTextans1, 3)

# %%
from transformers import pipeline
ZSclassifier = pipeline("zero-shot-classification",  model="facebook/bart-large-mnli")
# Out:
# Downloading:   0%|          | 0.00/1.15k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.63G [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/899k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/456k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.36M [00:00<?, ?B/s]

# %%
#sequence_to_classify = "one day I will see the world"
#predictedclasses = ZSclassifier(sequence_to_classify, ZEROSHOTcandidate_labels, multi_class=True)
#predictedclasses

# %%
AUTOKERASlistofcolumnNames = [ "CAT.isOffensiveText1", "NUM.isOffensiveText1softm0", "NUM.isOffensiveText1softm1"]
AUTOKERAScolumn_types = { 'CAT.isOffensiveText1': 'categorical'  , 
                         'NUM.isOffensiveText1softm0': 'numerical',
                         'NUM.isOffensiveText1softm1': 'numerical'}

# %%
for i in range (len(ZEROSHOTcandidate_labels)):
  print(ZEROSHOTcandidate_labels[i])
  AUTOKERASlistofcolumnNames.append('NUM.' + ZEROSHOTcandidate_labels[i])
  AUTOKERAScolumn_types[ 'NUM.' + ZEROSHOTcandidate_labels[i] ] = "numerical"
# Out:
# offensive
# non offensive
# racist
# non-racist
# toxic
# severe toxic
# pleasant in meaning
# obsence
# inflammatory
# insult
# profanity
# slavery

# %%
AUTOKERASlistofcolumnNames
# Out:
# ['CAT.isOffensiveText1',
#  'NUM.isOffensiveText1softm0',
#  'NUM.isOffensiveText1softm1',
#  'NUM.offensive',
#  'NUM.non offensive',
#  'NUM.racist',
#  'NUM.non-racist',
#  'NUM.toxic',
#  'NUM.severe toxic',
#  'NUM.pleasant in meaning',
#  'NUM.obsence',
#  'NUM.inflammatory',
#  'NUM.insult',
#  'NUM.profanity',
#  'NUM.slavery']

# %%
AUTOKERAScolumn_types
# Out:
# {'CAT.isOffensiveText1': 'categorical',
#  'NUM.isOffensiveText1softm0': 'numerical',
#  'NUM.isOffensiveText1softm1': 'numerical',
#  'NUM.offensive': 'numerical',
#  'NUM.non offensive': 'numerical',
#  'NUM.racist': 'numerical',
#  'NUM.non-racist': 'numerical',
#  'NUM.toxic': 'numerical',
#  'NUM.severe toxic': 'numerical',
#  'NUM.pleasant in meaning': 'numerical',
#  'NUM.obsence': 'numerical',
#  'NUM.inflammatory': 'numerical',
#  'NUM.insult': 'numerical',
#  'NUM.profanity': 'numerical',
#  'NUM.slavery': 'numerical'}

# %%
for i in range( countofRecordstoProcess ):  
  text1 =  dfraw['sentence'][i] 
  sequence_to_classify = str(text1)
  predictedclasses = ZSclassifier(sequence_to_classify, ZEROSHOTcandidate_labels, multi_label=True)
  for p in range(len(predictedclasses['labels'])):
    aZSlabel = 'NUM.' + predictedclasses['labels'][p]
    dfraw.at[i , aZSlabel ] =   round ( predictedclasses['scores'][p] , 3)

# %%
dfraw

# %%
from transformers import ViltProcessor, ViltForImagesAndTextClassification
import requests
from PIL import Image

processor = ViltProcessor.from_pretrained("dandelin/vilt-b32-finetuned-nlvr2")
model = ViltForImagesAndTextClassification.from_pretrained("dandelin/vilt-b32-finetuned-nlvr2")
# Out:
# Downloading:   0%|          | 0.00/251 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/320 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/797 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/456M [00:00<?, ?B/s]

# %%
def understnadImage1(image1 , text):
  encoding = processor([image1, image1], text, return_tensors="pt")
  # forward pass
  outputs = model(input_ids=encoding.input_ids, pixel_values=encoding.pixel_values.unsqueeze(0))
  logits = outputs.logits
  idx = logits.argmax(-1).item()
  #print("Predicted answer:", model.config.id2label[idx])
  scores = outputs[0][0].detach().numpy()
  scores = softmax(scores)  
  return idx, round ( scores[0] , 3)  , round ( scores[1] , 3)

# %%
for p in range( len(VISUALREASONING_FactorsALL_ColomnName) ):
  print(VISUALREASONING_FactorsALL_ColomnName[p])
# Out:
# NLVR.offensive
# NLVR.non offensive
# NLVR.extremely offensive
# NLVR.nudity or sexual
# NLVR.violence
# NLVR.abuse of women
# NLVR.black people as slaves
# NLVR.racist behavior
# NLVR.is a clipart
# NLVR.is filled with text

# %%
dfraw

# %%
from PIL import Image

# %%
image1 = Image.open(  '/content/nandri/Labelled Images/AGGHufY.png' , 'r' )

# %%
for i in range( countofRecordstoProcess):  
  image1 = Image.open( dfraw['image_name'][i]   )
  image_to_reason = image1.convert('RGB')

# %%
#!pip install Pillow==9.1
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting Pillow==9.1
#   Downloading Pillow-9.1.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.3 MB)
#      |████████████████████████████████| 4.3 MB 12.6 MB/s
# Installing collected packages: Pillow
#   Attempting uninstall: Pillow
#     Found existing installation: Pillow 5.3.0
#     Uninstalling Pillow-5.3.0:
#       Successfully uninstalled Pillow-5.3.0
# Successfully installed Pillow-9.1.0

# %%
import io

# %%
countofRecordstoProcess    = 718

# %%
for i in range( 0 , 2 ):  
  try:
    print(i)
    image1 = Image.open( dfraw['image_name'][i]  )
    image_to_reason = image1.convert('RGB')
    for p in range( len(VISUALREASONING_FactorsALL_ColomnName) ):
      isVisualAnsCAT, isVisualAns0NUM, isVisualAns1NUM  = understnadImage1(image_to_reason, VISUALREASONING_FactorsALL_Reasoning[p])
      dfraw.at[i , 'CAT.'+VISUALREASONING_FactorsALL_ColomnName[p] ] =  round( isVisualAnsCAT)
      dfraw.at[i , 'NUM.'+VISUALREASONING_FactorsALL_ColomnName[p] + '0' ] =  round( isVisualAns0NUM, 3)
      dfraw.at[i , 'NUM.'+VISUALREASONING_FactorsALL_ColomnName[p] + '1'] =  round( isVisualAns1NUM, 3)
  except :
    print("****************EXCEPTION*********" + str(i))
# Out:
# 0
# 1

# %%
def runme(m, n):
  for i in range( m, n ):  
    try:
      print(i)
      image1 = Image.open( dfraw['image_name'][i]  )
      image_to_reason = image1.convert('RGB')
      for p in range( len(VISUALREASONING_FactorsALL_ColomnName) ):
        isVisualAnsCAT, isVisualAns0NUM, isVisualAns1NUM  = understnadImage1(image_to_reason, VISUALREASONING_FactorsALL_Reasoning[p])
        dfraw.at[i , 'CAT.'+VISUALREASONING_FactorsALL_ColomnName[p] ] =  round( isVisualAnsCAT)
        dfraw.at[i , 'NUM.'+VISUALREASONING_FactorsALL_ColomnName[p] + '0' ] =  round( isVisualAns0NUM, 3)
        dfraw.at[i , 'NUM.'+VISUALREASONING_FactorsALL_ColomnName[p] + '1'] =  round( isVisualAns1NUM, 3)
    except :
      print("****************EXCEPTION*********" + str(i))

# %%
runme(4, 10)

# %%
for i in range(10, 720, 10):
  runme(i, i+10)

  dfraw.to_csv('processed4temp.csv')

  file1 = drive.CreateFile()
  file1.SetContentFile('processed4temp.csv')
  file1.Upload()

# %%
runme(4, 100)

dfraw.to_csv('processed4temp.csv')

file1 = drive.CreateFile()
file1.SetContentFile('processed4temp.csv')
file1.Upload()
# Out:
# 2
# 3

# %%
for i in range( 180 , 743 ):  
  try:
    print(i)
    image1 = Image.open( dfraw['image_name'][i]  )
    image_to_reason = image1.convert('RGB')
    for p in range( len(VISUALREASONING_FactorsALL_ColomnName) ):
      isVisualAnsCAT, isVisualAns0NUM, isVisualAns1NUM  = understnadImage1(image_to_reason, VISUALREASONING_FactorsALL_Reasoning[p])
      dfraw.at[i , 'CAT.'+VISUALREASONING_FactorsALL_ColomnName[p] ] =  round( isVisualAnsCAT)
      dfraw.at[i , 'NUM.'+VISUALREASONING_FactorsALL_ColomnName[p] + '0' ] =  round( isVisualAns0NUM, 3)
      dfraw.at[i , 'NUM.'+VISUALREASONING_FactorsALL_ColomnName[p] + '1'] =  round( isVisualAns1NUM, 3)
  except :
    print("****************EXCEPTION*********" + str(i))


dfraw.to_csv('processed3temp.csv')

file1 = drive.CreateFile()
file1.SetContentFile('processed3temp.csv')
file1.Upload()

# %%
dfraw

# %%
for i in range(len (VISUALREASONING_FactorsALL_ColomnName)):
  print( str(i) + ". " + VISUALREASONING_FactorsALL_ColomnName[i] + "   ---------------------      "   + VISUALREASONING_FactorsALL_Reasoning[i])
# Out:
# 0. NLVR.offensive   ---------------------      This image contains offensive content
# 1. NLVR.non offensive   ---------------------      This image contains non offensive content
# 2. NLVR.extremely offensive   ---------------------      This image contains extremely offensive content
# 3. NLVR.nudity or sexual   ---------------------      This image contains nudity or sexual content
# 4. NLVR.violence   ---------------------      This image contains violence content
# 5. NLVR.abuse of women   ---------------------      This image shows abuse of women
# 6. NLVR.black people as slaves   ---------------------      This image shows black people as slaves
# 7. NLVR.racist behavior   ---------------------      This image shows racist behavior
# 8. NLVR.is a clipart   ---------------------      This image is a clipart
# 9. NLVR.is filled with text   ---------------------      This image is filled with text

# %%
dfraw.head(2)
# Out:
#         image_name                                           sentence  \
# 0  LJ3r8Gy.jpg.png  OFFICIAL BERNIE SANDERS DRINKING GAME ! Every ...
# 1      qDnIIHA.png  2:28 PM THIS IS A WALL INSIDE A NAZI GAS CHAMB...
#
#           label DATASET  CAT.isOffensiveText1  NUM.isOffensiveText1softm0  \
# 0  Non-offensiv   TRAIN                   1.0                         0.5
# 1     offensive   TRAIN                   1.0                         0.5
#
#    NUM.isOffensiveText1softm1  NUM.offensive  NUM.inflammatory  NUM.profanity  \
# 0                         0.5          0.825             0.814          0.306
# 1                         0.5          0.996             0.991          0.361
#
#    ...  NUM.NLVR.black people as slaves1  CAT.NLVR.racist behavior  \
# 0  ...                             0.001                       0.0
# 1  ...                             0.036                       1.0
#
#    NUM.NLVR.racist behavior0  NUM.NLVR.racist behavior1  \
# 0                      0.909                      0.091
# 1                      0.340                      0.660
#
#    CAT.NLVR.is a clipart  NUM.NLVR.is a clipart0  NUM.NLVR.is a clipart1  \
# 0                    1.0                   0.002                   0.998
# 1                    1.0                   0.001                   0.999
#
#    CAT.NLVR.is filled with text  NUM.NLVR.is filled with text0  \
# 0                           1.0                            0.0
# 1                           1.0                            0.0
#
#    NUM.NLVR.is filled with text1
# 0                            1.0
# 1                            1.0
#
# [2 rows x 49 columns]

# %%
#from google.colab import drive
#drive.mount('/content/drive')
#from google.colab import files

# file1.SetContentFile('processed2Gold.csv')

# %%
drive = GoogleDrive(gauth)

# %%
# !pwd

# %%
# !ls *.csv

# %%
train_file_path = 'processed4temp.csv'

dfNew1 = pd.read_csv(train_file_path)

# %%
dfNew1

# %%
dfNew = dfNew1[dfNew1['DATASET']=='TEST']

# %%
dfNew.head(2)
# Out:
#      Unnamed: 0   image_name  \
# 594         594  jyxHhiB.png
# 595         595  we4hhWi.png
#
#                                               sentence      label DATASET  \
# 594  3 hrs Black nurse in Connecticut asked me if T...  offensive    TEST
# 595  I do n't believe that women have any rights , ...  offensive    TEST
#
#      CAT.isOffensiveText1  NUM.isOffensiveText1softm0  \
# 594                   1.0                         0.1
# 595                   1.0                         0.1
#
#      NUM.isOffensiveText1softm1  NUM.offensive  NUM.inflammatory  ...  \
# 594                         0.9          0.822             0.941  ...
# 595                         0.9          0.998             0.996  ...
#
#      NUM.NLVR.black people as slaves1  CAT.NLVR.racist behavior  \
# 594                             0.001                       1.0
# 595                             0.040                       1.0
#
#      NUM.NLVR.racist behavior0  NUM.NLVR.racist behavior1  \
# 594                      0.218                      0.782
# 595                      0.072                      0.928
#
#      CAT.NLVR.is a clipart  NUM.NLVR.is a clipart0  NUM.NLVR.is a clipart1  \
# 594                    0.0                   0.850                   0.150
# 595                    1.0                   0.191                   0.809
#
#      CAT.NLVR.is filled with text  NUM.NLVR.is filled with text0  \
# 594                           1.0                          0.057
# 595                           1.0                          0.005
#
#      NUM.NLVR.is filled with text1
# 594                          0.943
# 595                          0.995
#
# [2 rows x 50 columns]

# %%
del dfNew['Unnamed: 0']
del dfNew['image_name']
del dfNew['sentence']
del dfNew['DATASET']
#del dfNew['OCR']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-49-d09723197ce6> in <module>
# ----> 1 del dfNew['Unnamed: 0']
#       2 del dfNew['image_name']
#       3 del dfNew['sentence']
#       4 del dfNew['DATASET']
#       5 #del dfNew['OCR']
#
# NameError: name 'dfNew' is not defined

# %%
# !pip install autokeras
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting autokeras
#   Downloading autokeras-1.0.20-py3-none-any.whl (162 kB)
#      |████████████████████████████████| 162 kB 7.7 MB/s
# Requirement already satisfied: packaging in /usr/local/lib/python3.8/dist-packages (from autokeras) (21.3)
# Requirement already satisfied: pandas in /usr/local/lib/python3.8/dist-packages (from autokeras) (1.3.5)
# Collecting keras-tuner>=1.1.0
#   Downloading keras_tuner-1.1.3-py3-none-any.whl (135 kB)
#      |████████████████████████████████| 135 kB 66.8 MB/s
# Requirement already satisfied: tensorflow>=2.8.0 in /usr/local/lib/python3.8/dist-packages (from autokeras) (2.9.2)
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.8/dist-packages (from keras-tuner>=1.1.0->autokeras) (2.9.1)
# Requirement already satisfied: ipython in /usr/local/lib/python3.8/dist-packages (from keras-tuner>=1.1.0->autokeras) (7.9.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from keras-tuner>=1.1.0->autokeras) (1.21.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from keras-tuner>=1.1.0->autokeras) (2.23.0)
# Collecting kt-legacy
#   Downloading kt_legacy-1.0.4-py3-none-any.whl (9.6 kB)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow>=2.8.0->autokeras) (1.6.3)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.8/dist-packages (from tensorflow>=2.8.0->autokeras) (0.28.0)
# Requirement already satisfied: flatbuffers<2,>=1.12 in /usr/local/lib/python3.8/dist-packages (from tensorflow>=2.8.0->autokeras) (1.12)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /usr/local/lib/python3.8/dist-packages (from tensorflow>=2.8.0->autokeras) (1.1.2)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow>=2.8.0->autokeras) (3.1.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.8/dist-packages (from tensorflow>=2.8.0->autokeras) (1.51.1)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow>=2.8.0->autokeras) (1.15.0)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /usr/local/lib/python3.8/dist-packages (from tensorflow>=2.8.0->autokeras) (0.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.8/dist-packages (from tensorflow>=2.8.0->autokeras) (4.4.0)
# Requirement already satisfied: keras<2.10.0,>=2.9.0rc0 in /usr/local/lib/python3.8/dist-packages (from tensorflow>=2.8.0->autokeras) (2.9.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.8/dist-packages (from tensorflow>=2.8.0->autokeras) (0.2.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/dist-packages (from tensorflow>=2.8.0->autokeras) (57.4.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow>=2.8.0->autokeras) (14.0.6)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow>=2.8.0->autokeras) (1.3.0)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in /usr/local/lib/python3.8/dist-packages (from tensorflow>=2.8.0->autokeras) (3.19.6)
# Requirement already satisfied: tensorflow-estimator<2.10.0,>=2.9.0rc0 in /usr/local/lib/python3.8/dist-packages (from tensorflow>=2.8.0->autokeras) (2.9.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow>=2.8.0->autokeras) (2.1.1)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow>=2.8.0->autokeras) (1.14.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.8/dist-packages (from tensorflow>=2.8.0->autokeras) (3.3.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.8/dist-packages (from astunparse>=1.6.0->tensorflow>=2.8.0->autokeras) (0.38.4)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.8/dist-packages (from tensorboard->keras-tuner>=1.1.0->autokeras) (3.4.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.8/dist-packages (from tensorboard->keras-tuner>=1.1.0->autokeras) (0.6.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.8/dist-packages (from tensorboard->keras-tuner>=1.1.0->autokeras) (2.15.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.8/dist-packages (from tensorboard->keras-tuner>=1.1.0->autokeras) (1.8.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from tensorboard->keras-tuner>=1.1.0->autokeras) (1.0.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.8/dist-packages (from tensorboard->keras-tuner>=1.1.0->autokeras) (0.4.6)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.8/dist-packages (from google-auth<3,>=1.6.3->tensorboard->keras-tuner>=1.1.0->autokeras) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.8/dist-packages (from google-auth<3,>=1.6.3->tensorboard->keras-tuner>=1.1.0->autokeras) (4.9)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from google-auth<3,>=1.6.3->tensorboard->keras-tuner>=1.1.0->autokeras) (5.2.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.8/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard->keras-tuner>=1.1.0->autokeras) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.8/dist-packages (from markdown>=2.6.8->tensorboard->keras-tuner>=1.1.0->autokeras) (4.13.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.8/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard->keras-tuner>=1.1.0->autokeras) (3.11.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.8/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard->keras-tuner>=1.1.0->autokeras) (0.4.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests->keras-tuner>=1.1.0->autokeras) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->keras-tuner>=1.1.0->autokeras) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests->keras-tuner>=1.1.0->autokeras) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests->keras-tuner>=1.1.0->autokeras) (2022.9.24)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.8/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard->keras-tuner>=1.1.0->autokeras) (3.2.2)
# Requirement already satisfied: backcall in /usr/local/lib/python3.8/dist-packages (from ipython->keras-tuner>=1.1.0->autokeras) (0.2.0)
# Requirement already satisfied: prompt-toolkit<2.1.0,>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from ipython->keras-tuner>=1.1.0->autokeras) (2.0.10)
# Requirement already satisfied: pygments in /usr/local/lib/python3.8/dist-packages (from ipython->keras-tuner>=1.1.0->autokeras) (2.6.1)
# Requirement already satisfied: pexpect in /usr/local/lib/python3.8/dist-packages (from ipython->keras-tuner>=1.1.0->autokeras) (4.8.0)
# Collecting jedi>=0.10
#   Downloading jedi-0.18.2-py2.py3-none-any.whl (1.6 MB)
#      |████████████████████████████████| 1.6 MB 70.2 MB/s
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.8/dist-packages (from ipython->keras-tuner>=1.1.0->autokeras) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.8/dist-packages (from ipython->keras-tuner>=1.1.0->autokeras) (5.6.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.8/dist-packages (from ipython->keras-tuner>=1.1.0->autokeras) (4.4.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.8/dist-packages (from jedi>=0.10->ipython->keras-tuner>=1.1.0->autokeras) (0.8.3)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.8/dist-packages (from prompt-toolkit<2.1.0,>=2.0.0->ipython->keras-tuner>=1.1.0->autokeras) (0.2.5)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging->autokeras) (3.0.9)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.8/dist-packages (from pandas->autokeras) (2022.6)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.8/dist-packages (from pandas->autokeras) (2.8.2)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.8/dist-packages (from pexpect->ipython->keras-tuner>=1.1.0->autokeras) (0.7.0)
# Installing collected packages: jedi, kt-legacy, keras-tuner, autokeras
# Successfully installed autokeras-1.0.20 jedi-0.18.2 keras-tuner-1.1.3 kt-legacy-1.0.4

# %%
import autokeras as ak

# %%
dfNew.head()
# Out:
#             label  CAT.isOffensiveText1  NUM.isOffensiveText1softm0  \
# 594     offensive                   1.0                         0.1
# 595     offensive                   1.0                         0.1
# 596     offensive                   1.0                         0.1
# 597  Non-offensiv                   0.0                         0.9
# 598  Non-offensiv                   0.0                         0.9
#
#      NUM.isOffensiveText1softm1  NUM.offensive  NUM.inflammatory  \
# 594                         0.9          0.822             0.941
# 595                         0.9          0.998             0.996
# 596                         0.9          0.957             0.948
# 597                         0.1          0.104             0.385
# 598                         0.1          0.028             0.329
#
#      NUM.profanity  NUM.insult  NUM.toxic  NUM.pleasant in meaning  ...  \
# 594          0.376       0.536      0.527                    0.929  ...
# 595          0.912       0.988      0.987                    0.002  ...
# 596          0.983       0.915      0.736                    0.001  ...
# 597          0.326       0.192      0.300                    0.790  ...
# 598          0.247       0.005      0.002                    0.991  ...
#
#      NUM.NLVR.black people as slaves1  CAT.NLVR.racist behavior  \
# 594                             0.001                       1.0
# 595                             0.040                       1.0
# 596                             0.000                       0.0
# 597                             0.000                       0.0
# 598                             0.003                       0.0
#
#      NUM.NLVR.racist behavior0  NUM.NLVR.racist behavior1  \
# 594                      0.218                      0.782
# 595                      0.072                      0.928
# 596                      0.922                      0.078
# 597                      0.999                      0.001
# 598                      0.573                      0.427
#
#      CAT.NLVR.is a clipart  NUM.NLVR.is a clipart0  NUM.NLVR.is a clipart1  \
# 594                    0.0                   0.850                   0.150
# 595                    1.0                   0.191                   0.809
# 596                    1.0                   0.030                   0.970
# 597                    1.0                   0.001                   0.999
# 598                    1.0                   0.229                   0.771
#
#      CAT.NLVR.is filled with text  NUM.NLVR.is filled with text0  \
# 594                           1.0                          0.057
# 595                           1.0                          0.005
# 596                           1.0                          0.000
# 597                           1.0                          0.000
# 598                           1.0                          0.216
#
#      NUM.NLVR.is filled with text1
# 594                          0.943
# 595                          0.995
# 596                          1.000
# 597                          1.000
# 598                          0.784
#
# [5 rows x 46 columns]

# %%
dfraw.head()
# Out:
#         image_name                                           sentence  \
# 0  LJ3r8Gy.jpg.png  OFFICIAL BERNIE SANDERS DRINKING GAME ! Every ...
# 1      qDnIIHA.png  2:28 PM THIS IS A WALL INSIDE A NAZI GAS CHAMB...
# 2      1JQk5NF.png                o shit waddup ! BERNIE SANDERS COM
# 3        iMMNq.png  `` MITT ROMNEY IS THE WORST REPUBLICAN IN THE ...
# 4      jAi3iI1.png  Anonymous ( ID : duqdA1io a 08/05/16 ( Fri ) 1...
#
#           label DATASET  CAT.isOffensiveText1  NUM.isOffensiveText1softm0  \
# 0  Non-offensiv   TRAIN                   1.0                         0.5
# 1     offensive   TRAIN                   1.0                         0.5
# 2     offensive   TRAIN                   1.0                         0.1
# 3  Non-offensiv   TRAIN                   0.0                         0.8
# 4  Non-offensiv   TRAIN                   0.0                         0.8
#
#    NUM.isOffensiveText1softm1  NUM.offensive  NUM.inflammatory  NUM.profanity  \
# 0                         0.5          0.825             0.814          0.306
# 1                         0.5          0.996             0.991          0.361
# 2                         0.9          0.998             0.999          0.999
# 3                         0.2          0.694             0.855          0.218
# 4                         0.2          0.872             0.874          0.351
#
#    ...  NUM.NLVR.black people as slaves1  CAT.NLVR.racist behavior  \
# 0  ...                             0.001                       0.0
# 1  ...                             0.036                       1.0
# 2  ...                             0.003                       0.0
# 3  ...                             0.001                       0.0
# 4  ...                             0.093                       1.0
#
#    NUM.NLVR.racist behavior0  NUM.NLVR.racist behavior1  \
# 0                      0.909                      0.091
# 1                      0.340                      0.660
# 2                      0.877                      0.123
# 3                      0.932                      0.068
# 4                      0.008                      0.992
#
#    CAT.NLVR.is a clipart  NUM.NLVR.is a clipart0  NUM.NLVR.is a clipart1  \
# 0                    1.0                   0.002                   0.998
# 1                    1.0                   0.001                   0.999
# 2                    1.0                   0.089                   0.911
# 3                    1.0                   0.002                   0.998
# 4                    1.0                   0.001                   0.999
#
#    CAT.NLVR.is filled with text  NUM.NLVR.is filled with text0  \
# 0                           1.0                           0.00
# 1                           1.0                           0.00
# 2                           1.0                           0.03
# 3                           1.0                           0.00
# 4                           1.0                           0.00
#
#    NUM.NLVR.is filled with text1
# 0                           1.00
# 1                           1.00
# 2                           0.97
# 3                           1.00
# 4                           1.00
#
# [5 rows x 49 columns]

# %%
dfrawTRAINandVAL = dfraw.copy(deep=True)

# %%
len(dfrawTRAINandVAL)
# Out:
# 743

# %%
dfrawTRAINandVAL = dfrawTRAINandVAL[dfrawTRAINandVAL['DATASET']!='TEST']

# %%
len(dfrawTRAINandVAL)
# Out:
# 594

# %%
dfrawTRAINandVAL.head()
# Out:
#         image_name                                           sentence  \
# 0  LJ3r8Gy.jpg.png  OFFICIAL BERNIE SANDERS DRINKING GAME ! Every ...
# 1      qDnIIHA.png  2:28 PM THIS IS A WALL INSIDE A NAZI GAS CHAMB...
# 2      1JQk5NF.png                o shit waddup ! BERNIE SANDERS COM
# 3        iMMNq.png  `` MITT ROMNEY IS THE WORST REPUBLICAN IN THE ...
# 4      jAi3iI1.png  Anonymous ( ID : duqdA1io a 08/05/16 ( Fri ) 1...
#
#           label DATASET  CAT.isOffensiveText1  NUM.isOffensiveText1softm0  \
# 0  Non-offensiv   TRAIN                   1.0                         0.5
# 1     offensive   TRAIN                   1.0                         0.5
# 2     offensive   TRAIN                   1.0                         0.1
# 3  Non-offensiv   TRAIN                   0.0                         0.8
# 4  Non-offensiv   TRAIN                   0.0                         0.8
#
#    NUM.isOffensiveText1softm1  NUM.offensive  NUM.inflammatory  NUM.profanity  \
# 0                         0.5          0.825             0.814          0.306
# 1                         0.5          0.996             0.991          0.361
# 2                         0.9          0.998             0.999          0.999
# 3                         0.2          0.694             0.855          0.218
# 4                         0.2          0.872             0.874          0.351
#
#    ...  NUM.NLVR.black people as slaves1  CAT.NLVR.racist behavior  \
# 0  ...                             0.001                       0.0
# 1  ...                             0.036                       1.0
# 2  ...                             0.003                       0.0
# 3  ...                             0.001                       0.0
# 4  ...                             0.093                       1.0
#
#    NUM.NLVR.racist behavior0  NUM.NLVR.racist behavior1  \
# 0                      0.909                      0.091
# 1                      0.340                      0.660
# 2                      0.877                      0.123
# 3                      0.932                      0.068
# 4                      0.008                      0.992
#
#    CAT.NLVR.is a clipart  NUM.NLVR.is a clipart0  NUM.NLVR.is a clipart1  \
# 0                    1.0                   0.002                   0.998
# 1                    1.0                   0.001                   0.999
# 2                    1.0                   0.089                   0.911
# 3                    1.0                   0.002                   0.998
# 4                    1.0                   0.001                   0.999
#
#    CAT.NLVR.is filled with text  NUM.NLVR.is filled with text0  \
# 0                           1.0                           0.00
# 1                           1.0                           0.00
# 2                           1.0                           0.03
# 3                           1.0                           0.00
# 4                           1.0                           0.00
#
#    NUM.NLVR.is filled with text1
# 0                           1.00
# 1                           1.00
# 2                           0.97
# 3                           1.00
# 4                           1.00
#
# [5 rows x 49 columns]

# %%
dfrawTRAINandVAL
# Out:
#           image_name                                           sentence  \
# 0    LJ3r8Gy.jpg.png  OFFICIAL BERNIE SANDERS DRINKING GAME ! Every ...
# 1        qDnIIHA.png  2:28 PM THIS IS A WALL INSIDE A NAZI GAS CHAMB...
# 2        1JQk5NF.png                o shit waddup ! BERNIE SANDERS COM
# 3          iMMNq.png  `` MITT ROMNEY IS THE WORST REPUBLICAN IN THE ...
# 4        jAi3iI1.png  Anonymous ( ID : duqdA1io a 08/05/16 ( Fri ) 1...
# ..               ...                                                ...
# 589      iutC6Qy.png  Pussy almost brings down Trump Weiner knocks o...
# 590      yGHKtzg.png  CLINTON SAID SHE B BRINGING BACK RUGRATIS AM G...
# 591      phyDxAb.png  2 hrs THAT AwKWARD MoMENT wHEN ... I. BERNIE S...
# 592      Qj9x2wz.png  FOR HILLARY BLOOD ON YOUR HANDS Stop Voting ou...
# 593      1f2zSW8.png  Debate Site St. Louis 3:21 PM CT HARA ENTSPIZZ...
#
#             label DATASET  CAT.isOffensiveText1  NUM.isOffensiveText1softm0  \
# 0    Non-offensiv   TRAIN                   1.0                         0.5
# 1       offensive   TRAIN                   1.0                         0.5
# 2       offensive   TRAIN                   1.0                         0.1
# 3    Non-offensiv   TRAIN                   0.0                         0.8
# 4    Non-offensiv   TRAIN                   0.0                         0.8
# ..            ...     ...                   ...                         ...
# 589     offensive     VAL                   1.0                         0.5
# 590     offensive     VAL                   0.0                         0.8
# 591  Non-offensiv     VAL                   0.0                         0.6
# 592     offensive     VAL                   0.0                         0.9
# 593  Non-offensiv     VAL                   0.0                         0.8
#
#      NUM.isOffensiveText1softm1  NUM.offensive  NUM.inflammatory  \
# 0                           0.5          0.825             0.814
# 1                           0.5          0.996             0.991
# 2                           0.9          0.998             0.999
# 3                           0.2          0.694             0.855
# 4                           0.2          0.872             0.874
# ..                          ...            ...               ...
# 589                         0.5          0.919             0.990
# 590                         0.2          0.737             0.956
# 591                         0.4          0.994             0.986
# 592                         0.1          0.971             0.985
# 593                         0.2          0.464             0.939
#
#      NUM.profanity  ...  NUM.NLVR.black people as slaves1  \
# 0            0.306  ...                             0.001
# 1            0.361  ...                             0.036
# 2            0.999  ...                             0.003
# 3            0.218  ...                             0.001
# 4            0.351  ...                             0.093
# ..             ...  ...                               ...
# 589          0.991  ...                             0.001
# 590          0.742  ...                             0.973
# 591          0.665  ...                             0.000
# 592          0.651  ...                             0.007
# 593          0.940  ...                             0.001
#
#      CAT.NLVR.racist behavior  NUM.NLVR.racist behavior0  \
# 0                         0.0                      0.909
# 1                         1.0                      0.340
# 2                         0.0                      0.877
# 3                         0.0                      0.932
# 4                         1.0                      0.008
# ..                        ...                        ...
# 589                       0.0                      0.998
# 590                       1.0                      0.172
# 591                       1.0                      0.127
# 592                       1.0                      0.038
# 593                       1.0                      0.001
#
#      NUM.NLVR.racist behavior1  CAT.NLVR.is a clipart  NUM.NLVR.is a clipart0  \
# 0                        0.091                    1.0                   0.002
# 1                        0.660                    1.0                   0.001
# 2                        0.123                    1.0                   0.089
# 3                        0.068                    1.0                   0.002
# 4                        0.992                    1.0                   0.001
# ..                         ...                    ...                     ...
# 589                      0.002                    1.0                   0.376
# 590                      0.828                    1.0                   0.008
# 591                      0.873                    1.0                   0.236
# 592                      0.962                    1.0                   0.031
# 593                      0.999                    1.0                   0.000
#
#      NUM.NLVR.is a clipart1  CAT.NLVR.is filled with text  \
# 0                     0.998                           1.0
# 1                     0.999                           1.0
# 2                     0.911                           1.0
# 3                     0.998                           1.0
# 4                     0.999                           1.0
# ..                      ...                           ...
# 589                   0.624                           1.0
# 590                   0.992                           1.0
# 591                   0.764                           1.0
# 592                   0.969                           1.0
# 593                   1.000                           1.0
#
#      NUM.NLVR.is filled with text0  NUM.NLVR.is filled with text1
# 0                            0.000                          1.000
# 1                            0.000                          1.000
# 2                            0.030                          0.970
# 3                            0.000                          1.000
# 4                            0.000                          1.000
# ..                             ...                            ...
# 589                          0.001                          0.999
# 590                          0.000                          1.000
# 591                          0.000                          1.000
# 592                          0.001                          0.999
# 593                          0.000                          1.000
#
# [594 rows x 49 columns]

# %%
del dfrawTRAINandVAL['image_name']
del dfrawTRAINandVAL['sentence']
del dfrawTRAINandVAL['DATASET']
#del dfNew['OCR']

# %%
dfrawTRAINandVAL = dfrawTRAINandVAL[0:400]

# %%
len(dfrawTRAINandVAL)
# Out:
# 400

# %%
x_train = dfrawTRAINandVAL
print(type(x_train))  # pandas.DataFrame
y_train = x_train.pop("label")
print(type(y_train))  # pandas.Series
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.series.Series'>

# %%
x_train.head()
# Out:
#    CAT.isOffensiveText1  NUM.isOffensiveText1softm0  \
# 0                   1.0                         0.5
# 1                   1.0                         0.5
# 2                   1.0                         0.1
# 3                   0.0                         0.8
# 4                   0.0                         0.8
#
#    NUM.isOffensiveText1softm1  NUM.offensive  NUM.inflammatory  NUM.profanity  \
# 0                         0.5          0.825             0.814          0.306
# 1                         0.5          0.996             0.991          0.361
# 2                         0.9          0.998             0.999          0.999
# 3                         0.2          0.694             0.855          0.218
# 4                         0.2          0.872             0.874          0.351
#
#    NUM.insult  NUM.toxic  NUM.pleasant in meaning  NUM.severe toxic  ...  \
# 0       0.291      0.051                    0.035             0.030  ...
# 1       0.973      0.705                    0.001             0.368  ...
# 2       0.993      0.994                    0.000             0.991  ...
# 3       0.867      0.724                    0.010             0.493  ...
# 4       0.806      0.913                    0.062             0.877  ...
#
#    NUM.NLVR.black people as slaves1  CAT.NLVR.racist behavior  \
# 0                             0.001                       0.0
# 1                             0.036                       1.0
# 2                             0.003                       0.0
# 3                             0.001                       0.0
# 4                             0.093                       1.0
#
#    NUM.NLVR.racist behavior0  NUM.NLVR.racist behavior1  \
# 0                      0.909                      0.091
# 1                      0.340                      0.660
# 2                      0.877                      0.123
# 3                      0.932                      0.068
# 4                      0.008                      0.992
#
#    CAT.NLVR.is a clipart  NUM.NLVR.is a clipart0  NUM.NLVR.is a clipart1  \
# 0                    1.0                   0.002                   0.998
# 1                    1.0                   0.001                   0.999
# 2                    1.0                   0.089                   0.911
# 3                    1.0                   0.002                   0.998
# 4                    1.0                   0.001                   0.999
#
#    CAT.NLVR.is filled with text  NUM.NLVR.is filled with text0  \
# 0                           1.0                           0.00
# 1                           1.0                           0.00
# 2                           1.0                           0.03
# 3                           1.0                           0.00
# 4                           1.0                           0.00
#
#    NUM.NLVR.is filled with text1
# 0                           1.00
# 1                           1.00
# 2                           0.97
# 3                           1.00
# 4                           1.00
#
# [5 rows x 45 columns]

# %%
y_train.head()
# Out:
# 0    Non-offensiv
# 1       offensive
# 2       offensive
# 3    Non-offensiv
# 4    Non-offensiv
# Name: label, dtype: object

# %%
len(AUTOKERASlistofcolumnNames)
# Out:
# 15

# %%
AUTOKERASlistofcolumnNames
# Out:
# ['CAT.isOffensiveText1',
#  'NUM.isOffensiveText1softm0',
#  'NUM.isOffensiveText1softm1',
#  'NUM.offensive',
#  'NUM.non offensive',
#  'NUM.racist',
#  'NUM.non-racist',
#  'NUM.toxic',
#  'NUM.severe toxic',
#  'NUM.pleasant in meaning',
#  'NUM.obsence',
#  'NUM.inflammatory',
#  'NUM.insult',
#  'NUM.profanity',
#  'NUM.slavery']

# %%
AUTOKERAScolumn_types
# Out:
# {'CAT.isOffensiveText1': 'categorical',
#  'NUM.isOffensiveText1softm0': 'numerical',
#  'NUM.isOffensiveText1softm1': 'numerical',
#  'NUM.offensive': 'numerical',
#  'NUM.non offensive': 'numerical',
#  'NUM.racist': 'numerical',
#  'NUM.non-racist': 'numerical',
#  'NUM.toxic': 'numerical',
#  'NUM.severe toxic': 'numerical',
#  'NUM.pleasant in meaning': 'numerical',
#  'NUM.obsence': 'numerical',
#  'NUM.inflammatory': 'numerical',
#  'NUM.insult': 'numerical',
#  'NUM.profanity': 'numerical',
#  'NUM.slavery': 'numerical'}

# %%
VISUALREASONING_FactorsALL_ColomnName
# Out:
# ['NLVR.offensive',
#  'NLVR.non offensive',
#  'NLVR.extremely offensive',
#  'NLVR.nudity or sexual',
#  'NLVR.violence',
#  'NLVR.abuse of women',
#  'NLVR.black people as slaves',
#  'NLVR.racist behavior',
#  'NLVR.is a clipart',
#  'NLVR.is filled with text']

# %%
for i in range(len (VISUALREASONING_FactorsALL_ColomnName)):
  AUTOKERASlistofcolumnNames.append('CAT.' + VISUALREASONING_FactorsALL_ColomnName[i])  
  AUTOKERASlistofcolumnNames.append('NUM.' + VISUALREASONING_FactorsALL_ColomnName[i] + '0')
  AUTOKERASlistofcolumnNames.append('NUM.' + VISUALREASONING_FactorsALL_ColomnName[i] + '1')
  AUTOKERAScolumn_types[ 'CAT.' + VISUALREASONING_FactorsALL_ColomnName[i] ] = "categorical"
  AUTOKERAScolumn_types[ 'NUM.' + VISUALREASONING_FactorsALL_ColomnName[i] + '0'] = "numerical"
  AUTOKERAScolumn_types[ 'NUM.' + VISUALREASONING_FactorsALL_ColomnName[i] + '1'] = "numerical"

# %%
AUTOKERASlistofcolumnNames
# Out:
# ['CAT.isOffensiveText1',
#  'NUM.isOffensiveText1softm0',
#  'NUM.isOffensiveText1softm1',
#  'NUM.offensive',
#  'NUM.non offensive',
#  'NUM.racist',
#  'NUM.non-racist',
#  'NUM.toxic',
#  'NUM.severe toxic',
#  'NUM.pleasant in meaning',
#  'NUM.obsence',
#  'NUM.inflammatory',
#  'NUM.insult',
#  'NUM.profanity',
#  'NUM.slavery',
#  'CAT.NLVR.offensive',
#  'NUM.NLVR.offensive0',
#  'NUM.NLVR.offensive1',
#  'CAT.NLVR.non offensive',
#  'NUM.NLVR.non offensive0',
#  'NUM.NLVR.non offensive1',
#  'CAT.NLVR.extremely offensive',
#  'NUM.NLVR.extremely offensive0',
#  'NUM.NLVR.extremely offensive1',
#  'CAT.NLVR.nudity or sexual',
#  'NUM.NLVR.nudity or sexual0',
#  'NUM.NLVR.nudity or sexual1',
#  'CAT.NLVR.violence',
#  'NUM.NLVR.violence0',
#  'NUM.NLVR.violence1',
#  'CAT.NLVR.abuse of women',
#  'NUM.NLVR.abuse of women0',
#  'NUM.NLVR.abuse of women1',
#  'CAT.NLVR.black people as slaves',
#  'NUM.NLVR.black people as slaves0',
#  'NUM.NLVR.black people as slaves1',
#  'CAT.NLVR.racist behavior',
#  'NUM.NLVR.racist behavior0',
#  'NUM.NLVR.racist behavior1',
#  'CAT.NLVR.is a clipart',
#  'NUM.NLVR.is a clipart0',
#  'NUM.NLVR.is a clipart1',
#  'CAT.NLVR.is filled with text',
#  'NUM.NLVR.is filled with text0',
#  'NUM.NLVR.is filled with text1']

# %%
AUTOKERAScolumn_types
# Out:
# {'CAT.isOffensiveText1': 'categorical',
#  'NUM.isOffensiveText1softm0': 'numerical',
#  'NUM.isOffensiveText1softm1': 'numerical',
#  'NUM.offensive': 'numerical',
#  'NUM.non offensive': 'numerical',
#  'NUM.racist': 'numerical',
#  'NUM.non-racist': 'numerical',
#  'NUM.toxic': 'numerical',
#  'NUM.severe toxic': 'numerical',
#  'NUM.pleasant in meaning': 'numerical',
#  'NUM.obsence': 'numerical',
#  'NUM.inflammatory': 'numerical',
#  'NUM.insult': 'numerical',
#  'NUM.profanity': 'numerical',
#  'NUM.slavery': 'numerical',
#  'CAT.NLVR.offensive': 'categorical',
#  'NUM.NLVR.offensive0': 'numerical',
#  'NUM.NLVR.offensive1': 'numerical',
#  'CAT.NLVR.non offensive': 'categorical',
#  'NUM.NLVR.non offensive0': 'numerical',
#  'NUM.NLVR.non offensive1': 'numerical',
#  'CAT.NLVR.extremely offensive': 'categorical',
#  'NUM.NLVR.extremely offensive0': 'numerical',
#  'NUM.NLVR.extremely offensive1': 'numerical',
#  'CAT.NLVR.nudity or sexual': 'categorical',
#  'NUM.NLVR.nudity or sexual0': 'numerical',
#  'NUM.NLVR.nudity or sexual1': 'numerical',
#  'CAT.NLVR.violence': 'categorical',
#  'NUM.NLVR.violence0': 'numerical',
#  'NUM.NLVR.violence1': 'numerical',
#  'CAT.NLVR.abuse of women': 'categorical',
#  'NUM.NLVR.abuse of women0': 'numerical',
#  'NUM.NLVR.abuse of women1': 'numerical',
#  'CAT.NLVR.black people as slaves': 'categorical',
#  'NUM.NLVR.black people as slaves0': 'numerical',
#  'NUM.NLVR.black people as slaves1': 'numerical',
#  'CAT.NLVR.racist behavior': 'categorical',
#  'NUM.NLVR.racist behavior0': 'numerical',
#  'NUM.NLVR.racist behavior1': 'numerical',
#  'CAT.NLVR.is a clipart': 'categorical',
#  'NUM.NLVR.is a clipart0': 'numerical',
#  'NUM.NLVR.is a clipart1': 'numerical',
#  'CAT.NLVR.is filled with text': 'categorical',
#  'NUM.NLVR.is filled with text0': 'numerical',
#  'NUM.NLVR.is filled with text1': 'numerical'}

# %%
# Initialize the structured data classifier.
clf = ak.StructuredDataClassifier(
    column_names= AUTOKERASlistofcolumnNames ,
    column_types= AUTOKERAScolumn_types  ,
    max_trials=10,  # It tries 10 different models.
    overwrite=True,
)

# %%
clf.fit(x_train, y_train, validation_split=0.15, epochs=150)
# Out:
# Trial 10 Complete [00h 00m 11s]
# val_accuracy: 0.6875
#
# Best val_accuracy So Far: 0.9375
# Total elapsed time: 00h 01m 24s
# Epoch 1/150
# 13/13 [==============================] - 1s 6ms/step - loss: 0.7138 - accuracy: 0.5100
# Epoch 2/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.6561 - accuracy: 0.6000
# Epoch 3/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.6375 - accuracy: 0.6150
# Epoch 4/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.6263 - accuracy: 0.6300
# Epoch 5/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.6178 - accuracy: 0.6475
# Epoch 6/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.6100 - accuracy: 0.6525
# Epoch 7/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.6028 - accuracy: 0.6600
# Epoch 8/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.5964 - accuracy: 0.6700
# Epoch 9/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.5903 - accuracy: 0.6825
# Epoch 10/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.5842 - accuracy: 0.6800
# Epoch 11/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.5783 - accuracy: 0.6875
# Epoch 12/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.5722 - accuracy: 0.6925
# Epoch 13/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.5661 - accuracy: 0.7000
# Epoch 14/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.5598 - accuracy: 0.7000
# Epoch 15/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.5536 - accuracy: 0.7075
# Epoch 16/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.5475 - accuracy: 0.7075
# Epoch 17/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.5416 - accuracy: 0.7200
# Epoch 18/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.5356 - accuracy: 0.7200
# Epoch 19/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.5292 - accuracy: 0.7300
# Epoch 20/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.5230 - accuracy: 0.7400
# Epoch 21/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.5167 - accuracy: 0.7475
# Epoch 22/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.5104 - accuracy: 0.7600
# Epoch 23/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.5041 - accuracy: 0.7600
# Epoch 24/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.4979 - accuracy: 0.7650
# Epoch 25/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.4915 - accuracy: 0.7675
# Epoch 26/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.4852 - accuracy: 0.7650
# Epoch 27/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.4791 - accuracy: 0.7750
# Epoch 28/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.4729 - accuracy: 0.7800
# Epoch 29/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.4667 - accuracy: 0.7875
# Epoch 30/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.4605 - accuracy: 0.7925
# Epoch 31/150
# 13/13 [==============================] - 0s 7ms/step - loss: 0.4541 - accuracy: 0.8025
# Epoch 32/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.4479 - accuracy: 0.8025
# Epoch 33/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.4415 - accuracy: 0.8075
# Epoch 34/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.4349 - accuracy: 0.8075
# Epoch 35/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.4286 - accuracy: 0.8075
# Epoch 36/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.4220 - accuracy: 0.8125
# Epoch 37/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.4156 - accuracy: 0.8175
# Epoch 38/150
# 13/13 [==============================] - 0s 7ms/step - loss: 0.4089 - accuracy: 0.8150
# Epoch 39/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.4023 - accuracy: 0.8275
# Epoch 40/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.3955 - accuracy: 0.8275
# Epoch 41/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3892 - accuracy: 0.8300
# Epoch 42/150
# 13/13 [==============================] - 0s 7ms/step - loss: 0.3828 - accuracy: 0.8325
# Epoch 43/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.3769 - accuracy: 0.8375
# Epoch 44/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.3709 - accuracy: 0.8375
# Epoch 45/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.3649 - accuracy: 0.8425
# Epoch 46/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.3590 - accuracy: 0.8500
# Epoch 47/150
# 13/13 [==============================] - 0s 7ms/step - loss: 0.3533 - accuracy: 0.8525
# Epoch 48/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.3476 - accuracy: 0.8575
# Epoch 49/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3420 - accuracy: 0.8625
# Epoch 50/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.3361 - accuracy: 0.8700
# Epoch 51/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.3304 - accuracy: 0.8700
# Epoch 52/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.3248 - accuracy: 0.8725
# Epoch 53/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3194 - accuracy: 0.8800
# Epoch 54/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.3140 - accuracy: 0.8925
# Epoch 55/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.3088 - accuracy: 0.8950
# Epoch 56/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.3036 - accuracy: 0.8975
# Epoch 57/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.2987 - accuracy: 0.8975
# Epoch 58/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.2938 - accuracy: 0.8975
# Epoch 59/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.2890 - accuracy: 0.9000
# Epoch 60/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.2842 - accuracy: 0.9000
# Epoch 61/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.2797 - accuracy: 0.9000
# Epoch 62/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.2751 - accuracy: 0.9025
# Epoch 63/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.2708 - accuracy: 0.9025
# Epoch 64/150
# 13/13 [==============================] - 0s 7ms/step - loss: 0.2664 - accuracy: 0.9075
# Epoch 65/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2622 - accuracy: 0.9075
# Epoch 66/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.2581 - accuracy: 0.9075
# Epoch 67/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.2540 - accuracy: 0.9100
# Epoch 68/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.2501 - accuracy: 0.9150
# Epoch 69/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2459 - accuracy: 0.9225
# Epoch 70/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.2423 - accuracy: 0.9225
# Epoch 71/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.2381 - accuracy: 0.9250
# Epoch 72/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.2344 - accuracy: 0.9275
# Epoch 73/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2305 - accuracy: 0.9325
# Epoch 74/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.2268 - accuracy: 0.9325
# Epoch 75/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.2233 - accuracy: 0.9375
# Epoch 76/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.2195 - accuracy: 0.9375
# Epoch 77/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2160 - accuracy: 0.9400
# Epoch 78/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.2126 - accuracy: 0.9425
# Epoch 79/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.2091 - accuracy: 0.9425
# Epoch 80/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.2058 - accuracy: 0.9450
# Epoch 81/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.2024 - accuracy: 0.9450
# Epoch 82/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.1993 - accuracy: 0.9425
# Epoch 83/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.1961 - accuracy: 0.9450
# Epoch 84/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.1928 - accuracy: 0.9475
# Epoch 85/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.1898 - accuracy: 0.9500
# Epoch 86/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.1868 - accuracy: 0.9525
# Epoch 87/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.1838 - accuracy: 0.9500
# Epoch 88/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.1808 - accuracy: 0.9525
# Epoch 89/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.1778 - accuracy: 0.9525
# Epoch 90/150
# 13/13 [==============================] - 0s 7ms/step - loss: 0.1749 - accuracy: 0.9550
# Epoch 91/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.1720 - accuracy: 0.9550
# Epoch 92/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.1693 - accuracy: 0.9550
# Epoch 93/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.1663 - accuracy: 0.9550
# Epoch 94/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.1638 - accuracy: 0.9550
# Epoch 95/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.1610 - accuracy: 0.9550
# Epoch 96/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.1583 - accuracy: 0.9550
# Epoch 97/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.1558 - accuracy: 0.9575
# Epoch 98/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.1532 - accuracy: 0.9575
# Epoch 99/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.1508 - accuracy: 0.9575
# Epoch 100/150
# 13/13 [==============================] - 0s 7ms/step - loss: 0.1484 - accuracy: 0.9625
# Epoch 101/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.1457 - accuracy: 0.9625
# Epoch 102/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.1435 - accuracy: 0.9625
# Epoch 103/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.1412 - accuracy: 0.9625
# Epoch 104/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.1388 - accuracy: 0.9625
# Epoch 105/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.1365 - accuracy: 0.9650
# Epoch 106/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.1343 - accuracy: 0.9650
# Epoch 107/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.1321 - accuracy: 0.9650
# Epoch 108/150
# 13/13 [==============================] - 0s 7ms/step - loss: 0.1302 - accuracy: 0.9650
# Epoch 109/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.1277 - accuracy: 0.9650
# Epoch 110/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.1259 - accuracy: 0.9650
# Epoch 111/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.1235 - accuracy: 0.9650
# Epoch 112/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.1217 - accuracy: 0.9650
# Epoch 113/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.1196 - accuracy: 0.9650
# Epoch 114/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.1175 - accuracy: 0.9700
# Epoch 115/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.1156 - accuracy: 0.9700
# Epoch 116/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.1135 - accuracy: 0.9700
# Epoch 117/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.1115 - accuracy: 0.9700
# Epoch 118/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.1098 - accuracy: 0.9700
# Epoch 119/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.1078 - accuracy: 0.9700
# Epoch 120/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.1060 - accuracy: 0.9700
# Epoch 121/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.1042 - accuracy: 0.9700
# Epoch 122/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.1023 - accuracy: 0.9750
# Epoch 123/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.1008 - accuracy: 0.9775
# Epoch 124/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0991 - accuracy: 0.9775
# Epoch 125/150
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0972 - accuracy: 0.9775
# Epoch 126/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0959 - accuracy: 0.9775
# Epoch 127/150
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0940 - accuracy: 0.9775
# Epoch 128/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0926 - accuracy: 0.9775
# Epoch 129/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0912 - accuracy: 0.9775
# Epoch 130/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0894 - accuracy: 0.9800
# Epoch 131/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0881 - accuracy: 0.9825
# Epoch 132/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0867 - accuracy: 0.9825
# Epoch 133/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0851 - accuracy: 0.9850
# Epoch 134/150
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0837 - accuracy: 0.9850
# Epoch 135/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0823 - accuracy: 0.9850
# Epoch 136/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0808 - accuracy: 0.9875
# Epoch 137/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0794 - accuracy: 0.9875
# Epoch 138/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0780 - accuracy: 0.9875
# Epoch 139/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0767 - accuracy: 0.9875
# Epoch 140/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0757 - accuracy: 0.9875
# Epoch 141/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0743 - accuracy: 0.9900
# Epoch 142/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0730 - accuracy: 0.9875
# Epoch 143/150
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0718 - accuracy: 0.9900
# Epoch 144/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0706 - accuracy: 0.9900
# Epoch 145/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0693 - accuracy: 0.9900
# Epoch 146/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0683 - accuracy: 0.9925
# Epoch 147/150
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0671 - accuracy: 0.9925
# Epoch 148/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0661 - accuracy: 0.9925
# Epoch 149/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0648 - accuracy: 0.9925
# Epoch 150/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0639 - accuracy: 0.9925

# %%
# !pip install keras-tuner
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: keras-tuner in /usr/local/lib/python3.8/dist-packages (1.1.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.8/dist-packages (from keras-tuner) (21.3)
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.8/dist-packages (from keras-tuner) (2.9.1)
# Requirement already satisfied: ipython in /usr/local/lib/python3.8/dist-packages (from keras-tuner) (7.9.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from keras-tuner) (2.23.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from keras-tuner) (1.21.6)
# Requirement already satisfied: kt-legacy in /usr/local/lib/python3.8/dist-packages (from keras-tuner) (1.0.4)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.8/dist-packages (from ipython->keras-tuner) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.8/dist-packages (from ipython->keras-tuner) (5.6.0)
# Requirement already satisfied: pexpect in /usr/local/lib/python3.8/dist-packages (from ipython->keras-tuner) (4.8.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.8/dist-packages (from ipython->keras-tuner) (4.4.2)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.8/dist-packages (from ipython->keras-tuner) (57.4.0)
# Requirement already satisfied: backcall in /usr/local/lib/python3.8/dist-packages (from ipython->keras-tuner) (0.2.0)
# Requirement already satisfied: jedi>=0.10 in /usr/local/lib/python3.8/dist-packages (from ipython->keras-tuner) (0.18.2)
# Requirement already satisfied: prompt-toolkit<2.1.0,>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from ipython->keras-tuner) (2.0.10)
# Requirement already satisfied: pygments in /usr/local/lib/python3.8/dist-packages (from ipython->keras-tuner) (2.6.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.8/dist-packages (from jedi>=0.10->ipython->keras-tuner) (0.8.3)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.8/dist-packages (from prompt-toolkit<2.1.0,>=2.0.0->ipython->keras-tuner) (0.2.5)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.8/dist-packages (from prompt-toolkit<2.1.0,>=2.0.0->ipython->keras-tuner) (1.15.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging->keras-tuner) (3.0.9)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.8/dist-packages (from pexpect->ipython->keras-tuner) (0.7.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->keras-tuner) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests->keras-tuner) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests->keras-tuner) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests->keras-tuner) (2022.9.24)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.8/dist-packages (from tensorboard->keras-tuner) (1.8.1)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.8/dist-packages (from tensorboard->keras-tuner) (0.38.4)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in /usr/local/lib/python3.8/dist-packages (from tensorboard->keras-tuner) (3.19.6)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.8/dist-packages (from tensorboard->keras-tuner) (3.4.1)
# Requirement already satisfied: grpcio>=1.24.3 in /usr/local/lib/python3.8/dist-packages (from tensorboard->keras-tuner) (1.51.1)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.8/dist-packages (from tensorboard->keras-tuner) (1.3.0)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from tensorboard->keras-tuner) (1.0.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.8/dist-packages (from tensorboard->keras-tuner) (0.6.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.8/dist-packages (from tensorboard->keras-tuner) (0.4.6)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.8/dist-packages (from tensorboard->keras-tuner) (2.15.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.8/dist-packages (from google-auth<3,>=1.6.3->tensorboard->keras-tuner) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.8/dist-packages (from google-auth<3,>=1.6.3->tensorboard->keras-tuner) (4.9)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from google-auth<3,>=1.6.3->tensorboard->keras-tuner) (5.2.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.8/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard->keras-tuner) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.8/dist-packages (from markdown>=2.6.8->tensorboard->keras-tuner) (4.13.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.8/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard->keras-tuner) (3.11.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.8/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard->keras-tuner) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.8/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard->keras-tuner) (3.2.2)

# %%
y_pred = clf.predict(x_train)
# Out:
# 13/13 [==============================] - 1s 6ms/step
# 13/13 [==============================] - 0s 6ms/step

# %%
clf.evaluate(x_train, y_train)
# Out:
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0606 - accuracy: 0.9975
# [0.060641370713710785, 0.9975000023841858]

# %%
y_pred

# %%
import keras_tuner as kerastuner

# %%
# Initialize the structured data classifier.
clf = ak.StructuredDataClassifier(
    column_names= AUTOKERASlistofcolumnNames ,
    column_types= AUTOKERAScolumn_types  ,
    max_trials=300,  # It tries 10 different models.
    overwrite=False,
    objective = kerastuner.Objective("f1", direction="max"), 
    loss = 'binary_crossentropy'
    )

# %%
len(x_train)
# Out:
# 400

# %%
# Initialize the structured data classifier.
clf = ak.StructuredDataClassifier(
    column_names= AUTOKERASlistofcolumnNames ,
    column_types= AUTOKERAScolumn_types  ,
    max_trials=300,  # It tries 10 different models.
    overwrite=True,
    loss = 'binary_crossentropy', 
    metrics = 'accuracy' )

# %%
len(x_train)

# %%
clf.fit(x_train, y_train, validation_split=0.15, epochs=150)

# %%
len(x_train)

# %%
clf.fit(x_train, y_train, validation_split=0.15, epochs=150)

# %%
clf.fit(x_train, y_train, validation_split=0.10, epochs=150)

# %%
# Export as a Keras Model.

bestmodel = clf.export_model()

# %%
import tensorflow as tf
tf.keras.utils.plot_model(bestmodel,     show_shapes=True,
    show_dtype=True,
    show_layer_names=True,
    expand_nested=True,
    show_layer_activations=True)

# %%
try:
    bestmodel.save("model_autokeras", save_format="tf")
except Exception:
    bestmodel.save("model_autokeras.h5")

# %%
# Predict with the best model.
predicted_y = clf.predict(x_train)

# %%
dfraw.head(2)

# %%
def deletecolumsinDF(dftemp):
  del dftemp['image_name']
  del dftemp['sentence']
  del dftemp['DATASET']

# %%
dftemp

# %% [markdown]
# # Explainable Multimodal AI!
# ## Why the AI made that guess!

# %%
#@title  Select a Random input to test. { run: "auto" }

Random_slider = 112 #@param {type:"slider", min:0, max:400, step:1}


dftemp = dfraw.copy(deep=True)
dftemp = dftemp[Random_slider:Random_slider+1]
x_inferTEMP = dftemp.copy(deep=True)
deletecolumsinDF(x_inferTEMP)
y_TEMP = x_inferTEMP.pop("label")
print('           ********************************************     GROUND TRUTH is  =    ' + str( y_TEMP)  )

predicted_y = clf.predict(x_inferTEMP)
print('            ********************************************   PREDICTION by AI is =    ' + str(predicted_y)   )
explainMe(dftemp, Random_slider)

print('            **********************************  Hence, the  PREDICTION is =    ' + str(predicted_y)   )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-95-d6aefcfc5098> in <module>
#       7 dftemp = dftemp[Random_slider:Random_slider+1]
#       8 x_inferTEMP = dftemp.copy(deep=True)
# ----> 9 deletecolumsinDF(x_inferTEMP)
#      10 y_TEMP = x_inferTEMP.pop("label")
#      11 print('           ********************************************     GROUND TRUTH is  =    ' + str( y_TEMP)  )
#
# NameError: name 'deletecolumsinDF' is not defined

# %%
def explainMe(dftemp):

# %%
dftemp

# %%
from PIL import Image

# %%
explainMe(dftemp, 246)

# %%
type(dftemp['sentence']  )

# %%
def explainMe(dftemp, anumber):
  TEMPsequence_to_classify = dftemp['sentence'][anumber]
  print(TEMPsequence_to_classify)
  TEMPimage1 = Image.open(dftemp['image_name'][anumber])
  display(TEMPimage1.resize((200, 200), 0))
  TEMPimage1 = TEMPimage1.convert('RGB')


  TEMPpredictedclasses = ZSclassifier(TEMPsequence_to_classify, ZEROSHOTcandidate_labels, multi_label=True)
  for p in range(len(TEMPpredictedclasses['labels'])):
    print(  predictedclasses['labels'][p]  + " " +  str( round ( predictedclasses['scores'][p] , 2)))

  for p in range( len(VISUALREASONING_FactorsALL_ColomnName) ):
    isVisualAnsCAT, isVisualAns0NUM, isVisualAns1NUM  = understnadImage1(TEMPimage1, VISUALREASONING_FactorsALL_Reasoning[p])
    print( VISUALREASONING_FactorsALL_Reasoning[p] + " :  " + str( round( isVisualAnsCAT) )   + " |SOFTMAX|  " + str( round( isVisualAns0NUM, 4)  )  + " |  " + str( round( isVisualAns1NUM, 4)  ))

# %%
y_trainTEMP

# %%
predicted_y = clf.predict(x_trainTEMP)

# %%
predicted_y

# %%
# Evaluate the best model with testing data.
clf.evaluate(x_train, y_train)
